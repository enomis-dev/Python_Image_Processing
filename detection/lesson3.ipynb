# %% [markdown]
# # Learn how to use deep learning model yolov7 for object detection

# %% [markdown]
# In this notebook we will easy how to quickly use a state of the art algorithm to do object detection.
# - Link to the github project https://github.com/WongKinYiu/yolov7/tree/main/inference/images
# - Paper link https://arxiv.org/pdf/2207.02696.pdf

# %%
import os
from pathlib import Path

# %%
# clone git repo of the yolov7 project
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# fatal: destination path 'yolov7' already exists and is not an empty directory.

# %%
# install needed project reauirements
# !pip install -r yolov7/requirements.txt

# %%
# get the image path we want to analyze
source_path = Path().absolute().parent
image_path = os.path.join(source_path, 'Data', 'lena.png')

# %%
image_path
# Out:
# 'C:\\Users\\degas\\Documents\\Github\\Python_Image_Processing\\Data\\lena.png'

# %%
# set yolo repo as base dir
os.chdir("./yolov7/")

# %% [markdown]
# ### Use yolov7 api to do object detection
# Input parameters:
# - weights: model weights
# - conf: object confidence threshold
# - image-size: inference size (pixels)
# - source: input image

# %%
# copy image_path as source image on which to perform object detection

# %%
# !python detect.py --weights yolov7.pt --conf 0.25 --img-size 640 --source C:\\Users\\degas\\Documents\\Github\\Python_Image_Processing\\Data\\lena.png
# Out:
# Namespace(weights=['yolov7.pt'], source='C:\\\\Users\\\\degas\\\\Documents\\\\Github\\\\Python_Image_Processing\\\\Data\\\\lena.png', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 2 persons, Done. (1248.2ms) Inference, (19.7ms) NMS
#  The image with the result is saved in: runs\detect\exp3\lena.png
# Done. (1.305s)
# YOLOR  v0.1-122-g3b41c2c torch 2.0.1+cpu CPU
#
# Model Summary: 306 layers, 36905341 parameters, 6652669 gradients
# ...

# %%
# Results will be stored in the repo runs/detect/exp*/your_image name inside your yolov7 folder

# %% [markdown]
# The model output will be every object that has been identified in the source image with their confidence

# %% [markdown]
# ![lena.png](attachment:lena.png)
